# %%
import json, os, sys
# %load_ext autoreload
# %autoreload 2

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import cv2
import tensorflow as tf
from data.loader import load_segmentation, segmentation_process
from utils.session_config import setup_gpus

# %%
setup_gpus(True, 0.95)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
import numpy as np
from matplotlib import pyplot as plt
from pycocotools.coco import COCO
train_ids = np.load("annotations/train_ids.npy")
test_ids = np.load("annotations/val_ids.npy")
coco = COCO("annotations/integrated_annotation.json")
# Out:
# loading annotations into memory...
# Done (t=0.81s)
# creating index...
# index created!

# %% [markdown]
# # 학습데이터 생성 (파일저장) 이미 파일 생성했을 경우 실행 X

# %%
# patch_id = 0 
# for _id in train_ids:
#     print(patch_id)
#     patches, masks = segmentation_process(_id, coco, "detection")
#     for patch, mask in zip(patches, masks):
#         patch_id+=1
#         patch = cv2.resize(patch, [512,512], interpolation=cv2.INTER_NEAREST)
#         mask = cv2.resize(mask, [512,512], interpolation=cv2.INTER_NEAREST)
#         mask = mask[..., np.newaxis]
#         print(patch.shape)
#         print(mask.shape)
#         cv2.imwrite("segmentation/patches/train/{:06d}.png".format(patch_id), patch[:,:,::-1])
#         cv2.imwrite("segmentation/masks/train/{:06d}.png".format(patch_id), mask[:,:,::-1])

# %%
# patch_id = 0 
# for _id in test_ids:
#     print(patch_id)
#     patches, masks = segmentation_process(_id, coco, "detection")
#     for patch, mask in zip(patches, masks):
#         patch_id+=1
#         patch = cv2.resize(patch, [512,512], interpolation=cv2.INTER_NEAREST)
#         mask = cv2.resize(mask, [512,512], interpolation=cv2.INTER_NEAREST)
#         mask = mask[..., np.newaxis]
#         print(patch.shape)
#         print(mask.shape)
#         cv2.imwrite("segmentation/patches/test/{:06d}.png".format(patch_id), patch[:,:,::-1])
#         cv2.imwrite("segmentation/masks/test/{:06d}.png".format(patch_id), mask[:,:,::-1])

# %% [markdown]
# # data pipeline

# %%
split = tf.strings.split

def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    mask_path = tf.strings.join([parts[0], "masks", parts[2], parts[3]], separator='/')
    return mask_path

def data_process(file_path):
    patch = tf.io.read_file(file_path)
    patch = tf.image.decode_jpeg(patch, channels=3)
    patch = tf.cast(patch, tf.float32)/255.
    
    mask_path = get_label(file_path)
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_jpeg(mask, channels=1)
    mask = tf.where(mask==100, 1.0, 0.0)
    #mask = tf.squeeze(mask, axis=2)
    return patch, mask

# %%
split = "train"
train_ds = tf.data.Dataset.list_files("segmentation/patches/{}/*".format(split))
train_ds = train_ds.shuffle(buffer_size=10000, reshuffle_each_iteration=False)
train_ds = train_ds.map(data_process)
for p, q in train_ds.take(1):
    print(p.shape)
    print(q.shape)
# Out:
# (512, 512, 3)
# (512, 512, 1)

# %%
plt.imshow(p)

# %%
plt.imshow(q, cmap='gray')

# %%
split = "test"
test_ds = tf.data.Dataset.list_files("segmentation/patches/{}/*".format(split))
test_ds = test_ds.shuffle(buffer_size=10000, reshuffle_each_iteration=False)
test_ds = test_ds.map(data_process)
for p, q in test_ds.take(1):
    print(p.shape)
    print(q.shape)
# Out:
# (512, 512, 3)
# (512, 512, 1)

# %%
train_ds = train_ds.batch(32).prefetch(tf.data.experimental.AUTOTUNE)
test_ds = test_ds.batch(32).prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# # 모델 빌드 및 학습

# %%
model = tf.keras.models.load_model("models/test_segmentation.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
BCE = tf.keras.losses.BinaryCrossentropy()
loss_fn = tf.keras.losses.BinaryCrossentropy()

@tf.function
def train_step(patches, masks, model, optimizer, train_loss):
    with tf.GradientTape() as tape:
        preds = model(patches, training=True)
        loss = loss_fn(masks,preds)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    train_loss(loss)
    return loss
@tf.function
def test_step(patches, masks, model, test_loss):
    preds = model(patches, training=False)
    loss = BCE(masks,preds)
    test_loss(loss)
    return loss

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
test_loss = tf.keras.metrics.Mean(name='test_loss')

template = "Epoch {} : train loss {:5f}, val loss {:5f}"
optimizer= tf.keras.optimizers.Adam(learning_rate=1E-5)
EPOCH = 20

log_dir = "logs/segmentation-test-lrE-5"
summary_writer = tf.summary.create_file_writer(log_dir)

for epoch in range(1, EPOCH+1): 
    train_loss.reset_states()
    test_loss.reset_states()

    for i, (patches, masks) in enumerate(train_ds):
        loss = train_step(patches, masks, model, optimizer, train_loss)
        print("Epoch : {} train_step : {} loss {}".format(epoch, i, loss))
        
    for i, (patches, masks) in enumerate(test_ds):
        loss = test_step(patches, masks, model, test_loss)
        print("Epoch : {} test_step : {} loss {}".format(epoch, i, loss))
    print(template.format(epoch,
                      train_loss.result().numpy(),
                     test_loss.result().numpy()))

    with summary_writer.as_default():
        tf.summary.scalar('train_loss', train_loss.result(), step=epoch)
        tf.summary.scalar('test_loss', test_loss.result().numpy(), step=epoch)
    model.save("checkpoints/test_segmentation/model-{}.h5".format(epoch))
# Out:
# Epoch : 1 train_step : 0 loss 0.7410711646080017
# Epoch : 1 train_step : 1 loss 0.7381182909011841
# Epoch : 1 train_step : 2 loss 0.740182101726532
# Epoch : 1 train_step : 3 loss 0.7372644543647766
# Epoch : 1 train_step : 4 loss 0.7340713143348694
# Epoch : 1 train_step : 5 loss 0.7383929491043091
# Epoch : 1 train_step : 6 loss 0.7269164323806763
# Epoch : 1 train_step : 7 loss 0.7290825843811035
# Epoch : 1 train_step : 8 loss 0.7302015423774719
# Epoch : 1 train_step : 9 loss 0.7234560251235962
# Epoch : 1 train_step : 10 loss 0.7266554832458496
# Epoch : 1 train_step : 11 loss 0.7190592288970947
# Epoch : 1 train_step : 12 loss 0.7178390026092529
# Epoch : 1 train_step : 13 loss 0.7217573523521423
# Epoch : 1 train_step : 14 loss 0.713074803352356
# Epoch : 1 train_step : 15 loss 0.7164514064788818
# Epoch : 1 train_step : 16 loss 0.7163206934928894
# Epoch : 1 train_step : 17 loss 0.715629518032074
# Epoch : 1 train_step : 18 loss 0.7126846313476562
# Epoch : 1 train_step : 19 loss 0.709753692150116
# Epoch : 1 train_step : 20 loss 0.7029805779457092
# Epoch : 1 train_step : 21 loss 0.7009981274604797
# Epoch : 1 train_step : 22 loss 0.7018565535545349
# Epoch : 1 train_step : 23 loss 0.700644850730896
# Epoch : 1 train_step : 24 loss 0.6987771391868591
# Epoch : 1 train_step : 25 loss 0.6908215284347534
# Epoch : 1 train_step : 26 loss 0.6998745203018188
# Epoch : 1 train_step : 27 loss 0.6932359933853149
# Epoch : 1 train_step : 28 loss 0.69090735912323
# Epoch : 1 train_step : 29 loss 0.6854898929595947
# Epoch : 1 train_step : 30 loss 0.6903206706047058
# Epoch : 1 train_step : 31 loss 0.6903269290924072
# Epoch : 1 train_step : 32 loss 0.6858538389205933
# Epoch : 1 train_step : 33 loss 0.6769518852233887
# Epoch : 1 train_step : 34 loss 0.6848215460777283
# Epoch : 1 train_step : 35 loss 0.6754310131072998
# Epoch : 1 train_step : 36 loss 0.6731625199317932
# Epoch : 1 train_step : 37 loss 0.683030366897583
# Epoch : 1 train_step : 38 loss 0.685957670211792
# Epoch : 1 train_step : 39 loss 0.672988772392273
# Epoch : 1 train_step : 40 loss 0.6732785701751709
# Epoch : 1 train_step : 41 loss 0.6746391654014587
# Epoch : 1 train_step : 42 loss 0.6762343645095825
# Epoch : 1 train_step : 43 loss 0.6660389304161072
# Epoch : 1 train_step : 44 loss 0.6627634763717651
# Epoch : 1 train_step : 45 loss 0.662111759185791
# Epoch : 1 train_step : 46 loss 0.662135899066925
# Epoch : 1 train_step : 47 loss 0.65833580493927
# Epoch : 1 train_step : 48 loss 0.6626753807067871
# Epoch : 1 train_step : 49 loss 0.6554020643234253
# Epoch : 1 train_step : 50 loss 0.6603636741638184
# Epoch : 1 train_step : 51 loss 0.6501911878585815
# Epoch : 1 train_step : 52 loss 0.6589183807373047
# Epoch : 1 train_step : 53 loss 0.6505210399627686
# Epoch : 1 train_step : 54 loss 0.6517592668533325
# Epoch : 1 train_step : 55 loss 0.6405128836631775
# Epoch : 1 train_step : 56 loss 0.6430118680000305
# Epoch : 1 train_step : 57 loss 0.6437317132949829
# Epoch : 1 train_step : 58 loss 0.6440013647079468
# Epoch : 1 train_step : 59 loss 0.6425794363021851
# Epoch : 1 train_step : 60 loss 0.636222243309021
# Epoch : 1 train_step : 61 loss 0.6373668909072876
# Epoch : 1 train_step : 62 loss 0.6426736116409302
# Epoch : 1 train_step : 63 loss 0.6328467130661011
# Epoch : 1 train_step : 64 loss 0.6260160207748413
# Epoch : 1 train_step : 65 loss 0.6379537582397461
# Epoch : 1 train_step : 66 loss 0.6322087049484253
# Epoch : 1 train_step : 67 loss 0.6272286176681519
# Epoch : 1 train_step : 68 loss 0.6264218688011169
# Epoch : 1 train_step : 69 loss 0.643498420715332
# Epoch : 1 train_step : 70 loss 0.6187971830368042
# Epoch : 1 train_step : 71 loss 0.6277322173118591
# Epoch : 1 train_step : 72 loss 0.6239274144172668
# Epoch : 1 train_step : 73 loss 0.6264696717262268
# Epoch : 1 train_step : 74 loss 0.6178492903709412
# Epoch : 1 train_step : 75 loss 0.6292641758918762
# Epoch : 1 train_step : 76 loss 0.608256995677948
# Epoch : 1 train_step : 77 loss 0.6021106839179993
# Epoch : 1 train_step : 78 loss 0.6131592988967896
# Epoch : 1 train_step : 79 loss 0.6152786016464233
# Epoch : 1 train_step : 80 loss 0.5986689925193787
# Epoch : 1 train_step : 81 loss 0.6105799078941345
# Epoch : 1 train_step : 82 loss 0.5970864295959473
# Epoch : 1 train_step : 83 loss 0.5992403030395508
# Epoch : 1 train_step : 84 loss 0.5996572971343994
# Epoch : 1 train_step : 85 loss 0.6009163856506348
# Epoch : 1 train_step : 86 loss 0.5926409363746643
# Epoch : 1 train_step : 87 loss 0.5998050570487976
# Epoch : 1 train_step : 88 loss 0.5965758562088013
# Epoch : 1 train_step : 89 loss 0.5882229804992676
# Epoch : 1 train_step : 90 loss 0.5804829597473145
# Epoch : 1 train_step : 91 loss 0.587147057056427
# Epoch : 1 train_step : 92 loss 0.5912799835205078
# Epoch : 1 train_step : 93 loss 0.5894762277603149
